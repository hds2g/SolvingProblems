# %%
# Use this class to create binary trees.
class Node:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

    def __str__(self):
        return str(self.value)


# Implement your function below.
def is_bst(node, lower_lim=None, upper_lim=None):
    return False


# A function for creating a tree.
# Input:
# - mapping: a node-to-node mapping that shows how the tree should be constructed
# - head_value: the value that will be used for the head ndoe
# Output:
# - The head node of the resulting tree
def create_tree(mapping, head_value):
    head = Node(head_value)
    nodes = {head_value: head}
    for key, value in mapping.items():
        nodes[value[0]] = Node(value[0])
        nodes[value[1]] = Node(value[1])
    for key, value in mapping.items():
        nodes[key].left = nodes[value[0]]
        nodes[key].right = nodes[value[1]]
    return head


# NOTE: The following values will be used for testing your solution.

# The mapping we're going to use for constructing a tree.
# {0: [1, 2]} means that 0's left child is 1, and its right
# child is 2.
mapping1 = {0: [1, 2], 1: [3, 4], 2: [5, 6]}
mapping2 = {3: [1, 4], 1: [0, 2], 4: [5, 6]}
mapping3 = {3: [1, 5], 1: [0, 2], 5: [4, 6]}
mapping4 = {3: [1, 5], 1: [0, 4]}
head1 = create_tree(mapping1, 0)
# This tree is:
#  head1 = 0
#        /   \
#       1     2
#      /\    / \
#     3  4  5   6
head2 = create_tree(mapping2, 3)
# This tree is:
#  head2 = 3
#        /   \
#       1     4
#      /\    / \
#     0  2  5   6
head3 = create_tree(mapping3, 3)
# This tree is:
#  head3 = 3
#        /   \
#       1     5
#      /\    / \
#     0  2  4   6
head4 = create_tree(mapping4, 3)
# This tree is:
#  head4 = 3
#        /   \
#       1     5
#      /\
#     0  4

# is_bst(head1) should return False
# is_bst(head2) should return False
# is_bst(head3) should return True
# is_bst(head4) should return False

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None
    
class BST:
    def __init__(self, val):
        self.root = Node(val)
        
    def add(self, val):
        if self.root.val is None:
            self.root.val = val
        else:
            self.__add(self.root, val)
    
    def __add(self, cur, val):
        if cur.val < val:
            if cur.right is not None:
                self.__add(cur.right, val)
            else:
                cur.right = Node(val)
        else:
            if cur.right is not None:
                self.__add(cur.left,val)
            else:
                cur.left = Node(val)
    
def is_BST(bst): # 고쳐야함
    if bst is None:
        return False
    if bst.root.left is not None:
        if bst.root.left.val <= bst.root.val:
            __is_BST(bst.root.left)
        else:
            return False
    if bst.root.right is not None:
        if bst.root.right.val > bst.root.val:
            __is_BST(bst.root.right)
        else:
            return False
    return True

def __is_BST(node):
    
    if node is None:
        print("__is_BST node is None")
        return False
    if node.left is not None:
        if node.left.val <= node.val:
            __is_BST(node.left)
        else:
            return False
    else:
        return True
    
    if node.right is not None:
        if node.right.val > node.val:
            __is_BST(node.right)
        else:
            return False
        
bst = BST(10)
bst.add(5)
bst.add(4)
bst.add(3)
bst.add(2)
bst.add(1)
bst.add(7)
bst.add(9)
bst.add(6)
bst.add(8)
        
        
        
print(is_BST(bst))
# Out:
# True

# %%
# Use this class to create binary trees.
class Node:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

    def __str__(self):
        return str(self.value)


# Implement your function below.
def is_bst(node, lower_lim=None, upper_lim=None):
    if lower_lim and node.value < lower_lim:
        return False
    if upper_lim and upper_lim < node.value:
        return False

    is_left_bst = True
    is_right_bst = True
    if node.left:
        is_left_bst = is_bst(node.left, lower_lim, node.value)
    if is_left_bst and node.right:
        is_right_bst = is_bst(node.right, node.value, upper_lim)
    return is_left_bst and is_right_bst


# A function for creating a tree.
# Input:
# - mapping: a node-to-node mapping that shows how the tree should be constructed
# - head_value: the value that will be used for the head ndoe
# Output:
# - The head node of the resulting tree
def create_tree(mapping, head_value):
    head = Node(head_value)
    nodes = {head_value: head}
    for key, value in mapping.items():
        nodes[value[0]] = Node(value[0])
        nodes[value[1]] = Node(value[1])
    for key, value in mapping.items():
        nodes[key].left = nodes[value[0]]
        nodes[key].right = nodes[value[1]]
    return head


# NOTE: The following values will be used for testing your solution.

# The mapping we're going to use for constructing a tree.
# {0: [1, 2]} means that 0's left child is 1, and its right
# child is 2.
mapping1 = {0: [1, 2], 1: [3, 4], 2: [5, 6]}
mapping2 = {3: [1, 4], 1: [0, 2], 4: [5, 6]}
mapping3 = {3: [1, 5], 1: [0, 2], 5: [4, 6]}
mapping4 = {3: [1, 5], 1: [0, 4]}
head1 = create_tree(mapping1, 0)
# This tree is:
#  head1 = 0
#        /   \
#       1     2
#      /\    / \
#     3  4  5   6
head2 = create_tree(mapping2, 3)
# This tree is:
#  head2 = 3
#        /   \
#       1     4
#      /\    / \
#     0  2  5   6
head3 = create_tree(mapping3, 3)
# This tree is:
#  head3 = 3
#        /   \
#       1     5
#      /\    / \
#     0  2  4   6
head4 = create_tree(mapping4, 3)
# This tree is:
#  head4 = 3
#        /   \
#       1     5
#      /\
#     0  4

# is_bst(head1) should return False
# is_bst(head2) should return False
# is_bst(head3) should return True
# is_bst(head4) should return False

# %%
is_bst(head2)
# Out:
# False
